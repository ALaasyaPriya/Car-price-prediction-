# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car = pd.read_csv("carsdatas.csv")

# %%
car.shape
# Out:
# (892, 6)

# %%
car.head()
# Out:
#                                      name   company  year          price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006        425,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014        325,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014        575,000
#
#     km driven fuel type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       892 non-null    object
#  1   company    892 non-null    object
#  2   year       892 non-null    object
#  3   price      892 non-null    object
#  4   km driven  840 non-null    object
#  5   fuel type  837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car['year'].unique
# Out:
# <bound method Series.unique of 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 887    zest
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 892, dtype: object>

# %%
car['price'].unique
# Out:
# <bound method Series.unique of 0             80,000
# 1            425,000
# 2      Ask For Price
# 3            325,000
# 4            575,000
#            ...
# 887          310,000
# 888          260,000
# 889          390,000
# 890          180,000
# 891          160,000
# Name: price, Length: 892, dtype: object>

# %%
car['km driven'].unique
# Out:
# <bound method Series.unique of 0      45,000 kms
# 1          40 kms
# 2      22,000 kms
# 3      28,000 kms
# 4      36,000 kms
#           ...
# 887           NaN
# 888    27,000 kms
# 889    40,000 kms
# 890
# 891
# Name: km driven, Length: 892, dtype: object>

# %%
car['fuel type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
x=car.copy()

# %%
car=car[car['year'].str.isnumeric()]

# %%
car['year']=car['year'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       842 non-null    object
#  1   company    842 non-null    object
#  2   year       842 non-null    int32
#  3   price      842 non-null    object
#  4   km driven  840 non-null    object
#  5   fuel type  837 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 42.8+ KB

# %%
car=car[car['price']!="Ask For Price"]

# %%
car['price']=car['price'].str.replace(',','').astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       819 non-null    object
#  1   company    819 non-null    object
#  2   year       819 non-null    int32
#  3   price      819 non-null    int32
#  4   km driven  819 non-null    object
#  5   fuel type  816 non-null    object
# dtypes: int32(2), object(4)
# memory usage: 38.4+ KB

# %%
car['km driven']=car['km driven'].str.split(' ').str.get(0).str.replace(',','')

# %%
car=car[car['km driven'].str.isnumeric()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       817 non-null    object
#  1   company    817 non-null    object
#  2   year       817 non-null    int32
#  3   price      817 non-null    int32
#  4   km driven  817 non-null    object
#  5   fuel type  816 non-null    object
# dtypes: int32(2), object(4)
# memory usage: 38.3+ KB

# %%
car['km driven']=car['km driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       817 non-null    object
#  1   company    817 non-null    object
#  2   year       817 non-null    int32
#  3   price      817 non-null    int32
#  4   km driven  817 non-null    int32
#  5   fuel type  816 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 35.1+ KB

# %%
car[~car['fuel type'].isna()]
# Out:
#                                        name   company  year   price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      km driven fuel type
# 0        45000    Petrol
# 1           40    Diesel
# 3        28000    Petrol
# 4        36000    Diesel
# ...

# %%
car['name']=car['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       817 non-null    object
#  1   company    817 non-null    object
#  2   year       817 non-null    int32
#  3   price      817 non-null    int32
#  4   km driven  817 non-null    int32
#  5   fuel type  816 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 35.1+ KB

# %%
car['name']
# Out:
# 0         Hyundai Santro Xing
# 1         Mahindra Jeep CL550
# 3           Hyundai Grand i10
# 4      Ford EcoSport Titanium
# 6                   Ford Figo
#                 ...
# 883        Maruti Suzuki Ritz
# 885            Tata Indica V2
# 886      Toyota Corolla Altis
# 888              Tata Zest XM
# 889        Mahindra Quanto C8
# Name: name, Length: 817, dtype: object

# %%
car=car.reset_index(drop=True)

# %%
car
# Out:
#                        name   company  year   price  km driven fuel type
# 0       Hyundai Santro Xing   Hyundai  2007   80000      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000         40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000      28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000      36000    Diesel
# 4                 Ford Figo      Ford  2012  175000      41000    Diesel
# ..                      ...       ...   ...     ...        ...       ...
# 812      Maruti Suzuki Ritz    Maruti  2011  270000      50000    Petrol
# 813          Tata Indica V2      Tata  2009  110000      30000    Diesel
# 814    Toyota Corolla Altis    Toyota  2009  300000     132000    Petrol
# 815            Tata Zest XM      Tata  2018  260000      27000    Diesel
# 816      Mahindra Quanto C8  Mahindra  2013  390000      40000    Diesel
#
# [817 rows x 6 columns]

# %%
car.describe()
# Out:
#               year         price      km driven
# count   817.000000  8.170000e+02     817.000000
# mean   2012.440636  4.115503e+05   46250.714810
# std       4.002354  4.749173e+05   34283.745254
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.900000e+05   56758.000000
# max    2019.000000  8.500003e+06  400000.000000

# %%
car=car[car['price']<6e6].reset_index(drop=True)

# %%
car
# Out:
#                        name   company  year   price  km driven fuel type
# 0       Hyundai Santro Xing   Hyundai  2007   80000      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000         40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000      28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000      36000    Diesel
# 4                 Ford Figo      Ford  2012  175000      41000    Diesel
# ..                      ...       ...   ...     ...        ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000      50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000      30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000     132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000      27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000      40000    Diesel
#
# [816 rows x 6 columns]

# %%
car.to_csv('Cleaned_data.csv')

# %%
car.describe(include='all')
# Out:
#                        name company         year         price      km driven  \
# count                   816     816   816.000000  8.160000e+02     816.000000
# unique                  254      25          NaN           NaN            NaN
# top     Maruti Suzuki Swift  Maruti          NaN           NaN            NaN
# freq                     51     221          NaN           NaN            NaN
# mean                    NaN     NaN  2012.438725  4.016380e+05   46252.247549
# std                     NaN     NaN     4.004436  3.813805e+05   34304.743769
# min                     NaN     NaN  1995.000000  3.000000e+04       0.000000
# 25%                     NaN     NaN  2010.000000  1.750000e+05   27000.000000
# 50%                     NaN     NaN  2013.000000  2.999990e+05   41000.000000
# 75%                     NaN     NaN  2015.000000  4.900000e+05   56818.500000
# max                     NaN     NaN  2019.000000  3.100000e+06  400000.000000
#
#        fuel type
# ...

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='year',y='price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\Maturi Vivek\PycharmProjects\flaskProject\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Maturi Vivek\PycharmProjects\flaskProject\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Maturi Vivek\PycharmProjects\flaskProject\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Maturi Vivek\PycharmProjects\flaskProject\venv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.relplot(x='km driven',y='price',data=car,height=7,aspect=1.5)

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel type',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='fuel type', ylabel='price'>

# %%
ax=sns.relplot(x='company',y='price',data=car,hue='fuel type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
X=car.drop(columns='price')
y=car['price']

# %%
X
# Out:
#                        name   company  year  km driven fuel type
# 0       Hyundai Santro Xing   Hyundai  2007      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006         40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014      28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014      36000    Diesel
# 4                 Ford Figo      Ford  2012      41000    Diesel
# ..                      ...       ...   ...        ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011      50000    Petrol
# 812          Tata Indica V2      Tata  2009      30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009     132000    Petrol
# 814            Tata Zest XM      Tata  2018      27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013      40000    Diesel
#
# [816 rows x 5 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 811    270000
# 812    110000
# 813    300000
# 814    260000
# 815    390000
# Name: price, Length: 816, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test,=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel type']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8115610459237855

# %%
scores=[]
for i in range(1000):
    X_train, X_test, y_train, y_test,=train_test_split(X,y, test_size=0.2, random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 398

# %%
scores[np.argmax(scores)]
# Out:
# 0.8383071730266642

# %%
X_train, X_test, y_train, y_test,=train_test_split(X,y, test_size=0.2, random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8383071730266642

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']],columns=['name','company','year','km driven','fuel type']))
# Out:
# array([439634.7042814])

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([439634.7042814])

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#        'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#        'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#        'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#        'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#        'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#        'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#        'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#        'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...
